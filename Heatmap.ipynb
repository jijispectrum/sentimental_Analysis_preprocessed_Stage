# %%
# importing the modules
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# generating 2-D 10x10 matrix of random numbers
# from 1 to 100
data = np.random.randint(low = 1,
						high = 100,
						size = (10, 10))
print("The data to be plotted:\n")
print(data)

# plotting the heatmap
hm = sn.heatmap(data = data,annot=True)

# displaying the plotted heatmap
plt.show()
# Out:
# The data to be plotted:
#
# [[30 46 46  7 68 47 81 21 87 31]
#  [99 43  7 71 70 83 86 86 70 96]
#  [37 51 55 42 59 43 48 67 15 24]
#  [42 85 83 37  8  6 53 97  8 17]
#  [23 45 95 31 24 90 59 25 31 11]
#  [69 76 63 56 29 85 84  5 67 99]
#  [31 79 94  7 39 53 21 91 90 80]
#  [ 8 90 70 27 32 10 65 17 11 46]
#  [42 81 83 26 87 10  1 90  2 70]
#  [11 92 83 36 61 57  6 28 35 78]]
